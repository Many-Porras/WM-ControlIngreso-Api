-- %% [markdown]
-- # [dbo].[COLEGIO_WM]

-- %%
USE [BD_ControlIngresosGastos_WM]
GO

-- %%
/****** Object:  Table [dbo].[COLEGIO_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[COLEGIO_WM](
	[idColegio] [int] IDENTITY(1,1) NOT NULL,
	[idDistrito] [int] NOT NULL,
	[codigoModularColegio] [varchar](20) NOT NULL,
	[nombreColegio] [varchar](200) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idColegio] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[codigoModularColegio] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[COMITE_WM]

-- %%
/****** Object:  Table [dbo].[COMITE_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[COMITE_WM](
	[idComite] [int] IDENTITY(1,1) NOT NULL,
	[idColegio] [int] NOT NULL,
	[nombreComite] [varchar](150) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idComite] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DETALLE_INSUMO_WM]

-- %%
/****** Object:  Table [dbo].[DETALLE_INSUMO_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DETALLE_INSUMO_WM](
	[idDetalleInsumo] [int] IDENTITY(1,1) NOT NULL,
	[idInsumo] [int] NOT NULL,
	[idRaciones] [int] NOT NULL,
	[cantidadGramos] [decimal](10, 2) NULL,
	[cantidadKilogramos] [decimal](10, 2) NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idDetalleInsumo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DETALLE_LISTA_COMPRA_WM]

-- %%
/****** Object:  Table [dbo].[DETALLE_LISTA_COMPRA_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DETALLE_LISTA_COMPRA_WM](
	[idDetalleListaCompra] [int] IDENTITY(1,1) NOT NULL,
	[idListaCompra] [int] NOT NULL,
	[idDetalleInsumo] [int] NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idDetalleListaCompra] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DISTRITO_WM]

-- %%
/****** Object:  Table [dbo].[DISTRITO_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DISTRITO_WM](
	[idDistrito] [int] IDENTITY(1,1) NOT NULL,
	[idProvincia] [int] NOT NULL,
	[nombreDistrito] [varchar](150) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idDistrito] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[INSUMO_WM]

-- %%
/****** Object:  Table [dbo].[INSUMO_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[INSUMO_WM](
	[idInsumo] [int] IDENTITY(1,1) NOT NULL,
	[nombreInsumo] [varchar](150) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idInsumo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LISTA_COMPRA_WM]

-- %%
/****** Object:  Table [dbo].[LISTA_COMPRA_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LISTA_COMPRA_WM](
	[idListaCompra] [int] IDENTITY(1,1) NOT NULL,
	[idUsuario] [int] NOT NULL,
	[numeroCompras] [varchar](50) NOT NULL,
	[cantidadUsuarios] [int] NOT NULL,
	[nivelEducativo] [varchar](50) NOT NULL,
	[firma] [varchar](150) NULL,
	[idfirma] [int] NULL,
	[fechaDia] [datetime] NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idListaCompra] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PERFIL_WM]

-- %%
/****** Object:  Table [dbo].[PERFIL_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PERFIL_WM](
	[idPerfil] [int] IDENTITY(1,1) NOT NULL,
	[nombrePerfil] [varchar](150) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idPerfil] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PRESUPUESTO_WM]

-- %%
/****** Object:  Table [dbo].[PRESUPUESTO_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PRESUPUESTO_WM](
	[idPresupuesto] [int] IDENTITY(1,1) NOT NULL,
	[idComite] [int] NOT NULL,
	[idUsuario] [int] NOT NULL,
	[montoPresupuesto] [decimal](18, 2) NOT NULL,
	[fechaHoraPresupuesto] [datetime] NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idPresupuesto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PROVINCIA_WM]

-- %%
/****** Object:  Table [dbo].[PROVINCIA_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PROVINCIA_WM](
	[idProvincia] [int] IDENTITY(1,1) NOT NULL,
	[idRegion] [int] NOT NULL,
	[nombreProvincia] [varchar](150) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idProvincia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RACIONES_WM]

-- %%
/****** Object:  Table [dbo].[RACIONES_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RACIONES_WM](
	[idRaciones] [int] IDENTITY(1,1) NOT NULL,
	[nombreRacion] [varchar](150) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idRaciones] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[REGION_WM]

-- %%
/****** Object:  Table [dbo].[REGION_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[REGION_WM](
	[idRegion] [int] IDENTITY(1,1) NOT NULL,
	[nombreRegion] [varchar](150) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idRegion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[REGISTRO_ORDEN_COMPRA_WM]

-- %%
/****** Object:  Table [dbo].[REGISTRO_ORDEN_COMPRA_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[REGISTRO_ORDEN_COMPRA_WM](
	[idRegistroOrdenCompra] [int] IDENTITY(1,1) NOT NULL,
	[idDetalleListaCompra] [int] NOT NULL,
	[tipoSustento] [varchar](150) NOT NULL,
	[monto] [decimal](18, 2) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idRegistroOrdenCompra] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ROL_WM]

-- %%
/****** Object:  Table [dbo].[ROL_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ROL_WM](
	[idRol] [int] IDENTITY(1,1) NOT NULL,
	[idPerfil] [int] NOT NULL,
	[nombreRol] [varchar](150) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idRol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USUARIO_WM]

-- %%
/****** Object:  Table [dbo].[USUARIO_WM]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USUARIO_WM](
	[idUsuario] [int] IDENTITY(1,1) NOT NULL,
	[idRol] [int] NOT NULL,
	[idComite] [int] NULL,
	[nombreUsuario] [varchar](100) NOT NULL,
	[apellidoUsuario] [varchar](100) NOT NULL,
	[tipoDocumentoUsuario] [varchar](20) NOT NULL,
	[numeroDocumentoUsuario] [varchar](20) NOT NULL,
	[celularUsuario] [varchar](15) NULL,
	[passwordUsuario] [varchar](255) NOT NULL,
	[fechaCreacion] [datetime] NULL,
	[fechaUpdate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[idUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[numeroDocumentoUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__COLEGIO_W__fecha__49C3F6B7]

-- %%
ALTER TABLE [dbo].[COLEGIO_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__COMITE_WM__fecha__4D94879B]

-- %%
ALTER TABLE [dbo].[COMITE_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__DETALLE_I__fecha__619B8048]

-- %%
ALTER TABLE [dbo].[DETALLE_INSUMO_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__DETALLE_L__fecha__6A30C649]

-- %%
ALTER TABLE [dbo].[DETALLE_LISTA_COMPRA_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__DISTRITO___fecha__44FF419A]

-- %%
ALTER TABLE [dbo].[DISTRITO_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__INSUMO_WM__fecha__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[INSUMO_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__LISTA_COM__fecha__66603565]

-- %%
ALTER TABLE [dbo].[LISTA_COMPRA_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__PERFIL_WM__fecha__37A5467C]

-- %%
ALTER TABLE [dbo].[PERFIL_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__PRESUPUES__fecha__2EDAF651]

-- %%
ALTER TABLE [dbo].[PRESUPUESTO_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__PROVINCIA__fecha__412EB0B6]

-- %%
ALTER TABLE [dbo].[PROVINCIA_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__RACIONES___fecha__5EBF139D]

-- %%
ALTER TABLE [dbo].[RACIONES_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__REGION_WM__fecha__3E52440B]

-- %%
ALTER TABLE [dbo].[REGION_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__REGISTRO___fecha__6EF57B66]

-- %%
ALTER TABLE [dbo].[REGISTRO_ORDEN_COMPRA_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__ROL_WM__fechaCre__3A81B327]

-- %%
ALTER TABLE [dbo].[ROL_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF__USUARIO_W__fecha__52593CB8]

-- %%
ALTER TABLE [dbo].[USUARIO_WM] ADD  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [FK_COLEGIO_Distrito]

-- %%
ALTER TABLE [dbo].[COLEGIO_WM]  WITH CHECK ADD  CONSTRAINT [FK_COLEGIO_Distrito] FOREIGN KEY([idDistrito])
REFERENCES [dbo].[DISTRITO_WM] ([idDistrito])
GO
ALTER TABLE [dbo].[COLEGIO_WM] CHECK CONSTRAINT [FK_COLEGIO_Distrito]
GO

-- %% [markdown]
-- # [FK_COMITE_Colegio]

-- %%
ALTER TABLE [dbo].[COMITE_WM]  WITH CHECK ADD  CONSTRAINT [FK_COMITE_Colegio] FOREIGN KEY([idColegio])
REFERENCES [dbo].[COLEGIO_WM] ([idColegio])
GO
ALTER TABLE [dbo].[COMITE_WM] CHECK CONSTRAINT [FK_COMITE_Colegio]
GO

-- %% [markdown]
-- # [FK_DETALLEINSUMO_Insumo]

-- %%
ALTER TABLE [dbo].[DETALLE_INSUMO_WM]  WITH CHECK ADD  CONSTRAINT [FK_DETALLEINSUMO_Insumo] FOREIGN KEY([idInsumo])
REFERENCES [dbo].[INSUMO_WM] ([idInsumo])
GO
ALTER TABLE [dbo].[DETALLE_INSUMO_WM] CHECK CONSTRAINT [FK_DETALLEINSUMO_Insumo]
GO

-- %% [markdown]
-- # [FK_DETALLEINSUMO_Raciones]

-- %%
ALTER TABLE [dbo].[DETALLE_INSUMO_WM]  WITH CHECK ADD  CONSTRAINT [FK_DETALLEINSUMO_Raciones] FOREIGN KEY([idRaciones])
REFERENCES [dbo].[RACIONES_WM] ([idRaciones])
GO
ALTER TABLE [dbo].[DETALLE_INSUMO_WM] CHECK CONSTRAINT [FK_DETALLEINSUMO_Raciones]
GO

-- %% [markdown]
-- # [FK_DETALLELISTACOMPRA_DetalleInsumo]

-- %%
ALTER TABLE [dbo].[DETALLE_LISTA_COMPRA_WM]  WITH CHECK ADD  CONSTRAINT [FK_DETALLELISTACOMPRA_DetalleInsumo] FOREIGN KEY([idDetalleInsumo])
REFERENCES [dbo].[DETALLE_INSUMO_WM] ([idDetalleInsumo])
GO
ALTER TABLE [dbo].[DETALLE_LISTA_COMPRA_WM] CHECK CONSTRAINT [FK_DETALLELISTACOMPRA_DetalleInsumo]
GO

-- %% [markdown]
-- # [FK_DETALLELISTACOMPRA_Lista]

-- %%
ALTER TABLE [dbo].[DETALLE_LISTA_COMPRA_WM]  WITH CHECK ADD  CONSTRAINT [FK_DETALLELISTACOMPRA_Lista] FOREIGN KEY([idListaCompra])
REFERENCES [dbo].[LISTA_COMPRA_WM] ([idListaCompra])
GO
ALTER TABLE [dbo].[DETALLE_LISTA_COMPRA_WM] CHECK CONSTRAINT [FK_DETALLELISTACOMPRA_Lista]
GO

-- %% [markdown]
-- # [FK_DISTRITO_Provincia]

-- %%
ALTER TABLE [dbo].[DISTRITO_WM]  WITH CHECK ADD  CONSTRAINT [FK_DISTRITO_Provincia] FOREIGN KEY([idProvincia])
REFERENCES [dbo].[PROVINCIA_WM] ([idProvincia])
GO
ALTER TABLE [dbo].[DISTRITO_WM] CHECK CONSTRAINT [FK_DISTRITO_Provincia]
GO

-- %% [markdown]
-- # [FK_LISTACOMPRA_Usuario]

-- %%
ALTER TABLE [dbo].[LISTA_COMPRA_WM]  WITH CHECK ADD  CONSTRAINT [FK_LISTACOMPRA_Usuario] FOREIGN KEY([idUsuario])
REFERENCES [dbo].[USUARIO_WM] ([idUsuario])
GO
ALTER TABLE [dbo].[LISTA_COMPRA_WM] CHECK CONSTRAINT [FK_LISTACOMPRA_Usuario]
GO

-- %% [markdown]
-- # [FK_PRESUPUESTO_Comite]

-- %%
ALTER TABLE [dbo].[PRESUPUESTO_WM]  WITH CHECK ADD  CONSTRAINT [FK_PRESUPUESTO_Comite] FOREIGN KEY([idComite])
REFERENCES [dbo].[COMITE_WM] ([idComite])
GO
ALTER TABLE [dbo].[PRESUPUESTO_WM] CHECK CONSTRAINT [FK_PRESUPUESTO_Comite]
GO

-- %% [markdown]
-- # [FK_PRESUPUESTO_Usuario]

-- %%
ALTER TABLE [dbo].[PRESUPUESTO_WM]  WITH CHECK ADD  CONSTRAINT [FK_PRESUPUESTO_Usuario] FOREIGN KEY([idUsuario])
REFERENCES [dbo].[USUARIO_WM] ([idUsuario])
GO
ALTER TABLE [dbo].[PRESUPUESTO_WM] CHECK CONSTRAINT [FK_PRESUPUESTO_Usuario]
GO

-- %% [markdown]
-- # [FK_PROVINCIA_Region]

-- %%
ALTER TABLE [dbo].[PROVINCIA_WM]  WITH CHECK ADD  CONSTRAINT [FK_PROVINCIA_Region] FOREIGN KEY([idRegion])
REFERENCES [dbo].[REGION_WM] ([idRegion])
GO
ALTER TABLE [dbo].[PROVINCIA_WM] CHECK CONSTRAINT [FK_PROVINCIA_Region]
GO

-- %% [markdown]
-- # [FK_ORDENCOMPRA_DetalleLista]

-- %%
ALTER TABLE [dbo].[REGISTRO_ORDEN_COMPRA_WM]  WITH CHECK ADD  CONSTRAINT [FK_ORDENCOMPRA_DetalleLista] FOREIGN KEY([idDetalleListaCompra])
REFERENCES [dbo].[DETALLE_LISTA_COMPRA_WM] ([idDetalleListaCompra])
GO
ALTER TABLE [dbo].[REGISTRO_ORDEN_COMPRA_WM] CHECK CONSTRAINT [FK_ORDENCOMPRA_DetalleLista]
GO

-- %% [markdown]
-- # [FK_ROL_Perfil]

-- %%
ALTER TABLE [dbo].[ROL_WM]  WITH CHECK ADD  CONSTRAINT [FK_ROL_Perfil] FOREIGN KEY([idPerfil])
REFERENCES [dbo].[PERFIL_WM] ([idPerfil])
GO
ALTER TABLE [dbo].[ROL_WM] CHECK CONSTRAINT [FK_ROL_Perfil]
GO

-- %% [markdown]
-- # [FK_USUARIO_Comite]

-- %%
ALTER TABLE [dbo].[USUARIO_WM]  WITH CHECK ADD  CONSTRAINT [FK_USUARIO_Comite] FOREIGN KEY([idComite])
REFERENCES [dbo].[COMITE_WM] ([idComite])
GO
ALTER TABLE [dbo].[USUARIO_WM] CHECK CONSTRAINT [FK_USUARIO_Comite]
GO

-- %% [markdown]
-- # [FK_USUARIO_Rol]

-- %%
ALTER TABLE [dbo].[USUARIO_WM]  WITH CHECK ADD  CONSTRAINT [FK_USUARIO_Rol] FOREIGN KEY([idRol])
REFERENCES [dbo].[ROL_WM] ([idRol])
GO
ALTER TABLE [dbo].[USUARIO_WM] CHECK CONSTRAINT [FK_USUARIO_Rol]
GO

-- %% [markdown]
-- # [dbo].[sp_ActualizarMontoSubvencion]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ActualizarMontoSubvencion]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_ActualizarMontoSubvencion]
    @idComite INT,
    @idUsuario INT,
    @monto DECIMAL(18,2)
AS
BEGIN
    SET NOCOUNT ON;

    -- Verificar que el usuario tenga rol "administradorWM" y perfil "superAdministradorWM"
    IF NOT EXISTS (
        SELECT 1
        FROM USUARIO_WM u
        INNER JOIN ROL_WM r ON u.idRol = r.idRol
        INNER JOIN PERFIL_WM p ON r.idPerfil = p.idPerfil
        WHERE u.idUsuario = @idUsuario
          AND r.nombreRol = 'administradorWM'
          AND p.nombrePerfil = 'superAdministradorWM'
    )
    BEGIN
        PRINT 'Usuario no autorizado para actualizar el monto.';
        RETURN;
    END

    -- Verificar si ya existe un presupuesto para ese comité y usuario
    IF EXISTS (
        SELECT 1 
        FROM PRESUPUESTO_WM 
        WHERE idComite = @idComite 
          AND idUsuario = @idUsuario
    )
    BEGIN
        -- Actualizar el monto existente
        UPDATE PRESUPUESTO_WM
        SET montoPresupuesto = @monto, fechaUpdate = GETDATE()
        WHERE idComite = @idComite 
          AND idUsuario = @idUsuario;
    END
    ELSE
    BEGIN
        PRINT 'No se encontró el registro de presupuesto para este comité y usuario.';
    END
END;
GO

-- %% [markdown]
-- # [dbo].[sp_ActualizarMontoSubvencion2]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ActualizarMontoSubvencion2]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_ActualizarMontoSubvencion2]
    @idComite INT,
    @idUsuario INT,
    @monto DECIMAL(18,2),
    @Mes INT,       -- Mes (1=Enero, 2=Febrero, etc.)
    @Anio INT       -- Año (por ejemplo, 2025)
AS
BEGIN
    SET NOCOUNT ON;

    -- Verificar que el usuario tenga rol "administradorWM" y perfil "superAdministradorWM"
    IF NOT EXISTS (
        SELECT 1
        FROM USUARIO_WM u
        INNER JOIN ROL_WM r ON u.idRol = r.idRol
        INNER JOIN PERFIL_WM p ON r.idPerfil = p.idPerfil
        WHERE u.idUsuario = @idUsuario
          AND r.nombreRol = 'administradorWM'
          AND p.nombrePerfil = 'superAdministradorWM'
    )
    BEGIN
        PRINT 'Usuario no autorizado para actualizar el monto.';
        RETURN;
    END

    -- Verificar si ya existe un presupuesto para ese comité y usuario en el mes y año especificados
    IF EXISTS (
        SELECT 1 
        FROM PRESUPUESTO_WM 
        WHERE idComite = @idComite 
          AND idUsuario = @idUsuario
          AND DATEPART(MONTH, fechaHoraPresupuesto) = @Mes
          AND DATEPART(YEAR, fechaHoraPresupuesto) = @Anio
    )
    BEGIN
        -- Actualizar el monto existente
        UPDATE PRESUPUESTO_WM
        SET montoPresupuesto = @monto, fechaUpdate = GETDATE()
        WHERE idComite = @idComite 
          AND idUsuario = @idUsuario
          AND DATEPART(MONTH, fechaHoraPresupuesto) = @Mes
          AND DATEPART(YEAR, fechaHoraPresupuesto) = @Anio;
    END
    ELSE
    BEGIN
        PRINT 'No se encontró el registro de presupuesto para este comité, usuario y fecha especificada.';
    END
END;
GO

-- %% [markdown]
-- # [dbo].[sp_ListarRacionesOptimizado]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ListarRacionesOptimizado]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[sp_ListarRacionesOptimizado]

AS
BEGIN

	SET NOCOUNT ON;

    SELECT 
        idRaciones,
        nombreRacion,
        ISNULL(fechaCreacion, GETDATE()) AS fechaCreacion, -- Maneja NULLs
        ISNULL(fechaUpdate, fechaCreacion) AS fechaUpdate   -- Si no se ha actualizado, usa la fecha de creación
    FROM RACIONES_WM
    ORDER BY idRaciones ASC; -- Ordena alfabéticamente
END
GO

-- %% [markdown]
-- # [dbo].[sp_ListarSubvenciones]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ListarSubvenciones]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_ListarSubvenciones]
    @Mes INT = NULL,         -- Mes (1=Enero, 2=Febrero, etc.)
    @Anio INT = NULL         -- Año (ej. 2025)
AS
BEGIN
    SET NOCOUNT ON;

    WITH Meses AS (
    SELECT 1 AS Mes UNION ALL SELECT 2 UNION ALL SELECT 3 UNION ALL 
    SELECT 4 UNION ALL SELECT 5 UNION ALL SELECT 6 UNION ALL 
    SELECT 7 UNION ALL SELECT 8 UNION ALL SELECT 9 UNION ALL 
    SELECT 10 UNION ALL SELECT 11 UNION ALL SELECT 12
)
SELECT 
    m.Mes,
    r.nombreRegion AS Region,
    p.nombreProvincia AS Provincia,
    d.nombreDistrito AS Distrito,
    c.nombreColegio AS Colegio,
    com.idComite AS idComite,
    com.nombreComite AS Comite,
    ISNULL(pres.montoPresupuesto, 0) AS Monto,
    CASE 
        WHEN pres.montoPresupuesto IS NULL THEN 'Ingresar monto'
        ELSE 'Editar monto'
    END AS Estado
FROM Meses m
CROSS JOIN COMITE_WM com
INNER JOIN COLEGIO_WM c ON com.idColegio = c.idColegio
INNER JOIN DISTRITO_WM d ON c.idDistrito = d.idDistrito
INNER JOIN PROVINCIA_WM p ON d.idProvincia = p.idProvincia
INNER JOIN REGION_WM r ON p.idRegion = r.idRegion
LEFT JOIN PRESUPUESTO_WM pres 
    ON com.idComite = pres.idComite
    AND DATEPART(MONTH, pres.fechaHoraPresupuesto) = m.Mes
    AND (@Anio IS NULL OR DATEPART(YEAR, pres.fechaHoraPresupuesto) = @Anio)
	where m.mes = @Mes
ORDER BY m.Mes, com.nombreComite;
END;

GO

-- %% [markdown]
-- # [dbo].[sp_ListarSubvenciones2]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ListarSubvenciones2]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_ListarSubvenciones2]
    @Mes INT = NULL,         -- Mes (1=Enero, 2=Febrero, etc.)
    @Anio INT = NULL         -- Año (ej. 2025)
AS
BEGIN
    SET NOCOUNT ON;

    WITH Meses AS (
    SELECT 1 AS Mes UNION ALL SELECT 2 UNION ALL SELECT 3 UNION ALL 
    SELECT 4 UNION ALL SELECT 5 UNION ALL SELECT 6 UNION ALL 
    SELECT 7 UNION ALL SELECT 8 UNION ALL SELECT 9 UNION ALL 
    SELECT 10 UNION ALL SELECT 11 UNION ALL SELECT 12
)
SELECT 
    m.Mes,
    r.nombreRegion AS Region,
    p.nombreProvincia AS Provincia,
    d.nombreDistrito AS Distrito,
    c.nombreColegio AS Colegio,
    com.idComite AS idComite,
    com.nombreComite AS Comite,
    ISNULL(pres.montoPresupuesto, 0) AS Monto,
    CASE 
        WHEN pres.montoPresupuesto IS NULL THEN 'Ingresar monto'
        ELSE 'Editar monto'
    END AS Estado
FROM Meses m
CROSS JOIN COMITE_WM com
INNER JOIN COLEGIO_WM c ON com.idColegio = c.idColegio
INNER JOIN DISTRITO_WM d ON c.idDistrito = d.idDistrito
INNER JOIN PROVINCIA_WM p ON d.idProvincia = p.idProvincia
INNER JOIN REGION_WM r ON p.idRegion = r.idRegion
LEFT JOIN PRESUPUESTO_WM pres 
    ON com.idComite = pres.idComite
    AND DATEPART(MONTH, pres.fechaHoraPresupuesto) = m.Mes
    AND (@Anio IS NULL OR DATEPART(YEAR, pres.fechaHoraPresupuesto) = @Anio)
	where m.mes = @Mes
ORDER BY m.Mes, com.nombreComite;
END;
GO

-- %% [markdown]
-- # [dbo].[sp_LoginUsuarioByRolPerfil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_LoginUsuarioByRolPerfil]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_LoginUsuarioByRolPerfil]
    @numeroDocumentoUsuario VARCHAR(20),
    @passwordUsuario VARCHAR(255),
    @idPerfil INT = NULL,  -- Opcional: para restringir por perfil
    @idRol INT = NULL      -- Opcional: para restringir por rol
AS
BEGIN
    SET NOCOUNT ON;

    SELECT 
        u.idUsuario,
        u.nombreUsuario,
        u.apellidoUsuario,
        u.numeroDocumentoUsuario,
        r.idRol,
        r.nombreRol,
        p.idPerfil,
        p.nombrePerfil,
        u.fechaCreacion
    FROM USUARIO_WM u
    INNER JOIN ROL_WM r ON u.idRol = r.idRol
    INNER JOIN PERFIL_WM p ON r.idPerfil = p.idPerfil
    WHERE u.numeroDocumentoUsuario = @numeroDocumentoUsuario
      AND u.passwordUsuario = @passwordUsuario
      AND (@idPerfil IS NULL OR p.idPerfil = @idPerfil)
      AND (@idRol IS NULL OR r.idRol = @idRol);
END;
GO

-- %% [markdown]
-- # [dbo].[sp_RegistrarMontoSubvencion]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_RegistrarMontoSubvencion]    Script Date: 4/03/2025 10:31:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_RegistrarMontoSubvencion]
    @idComite INT,
    @idUsuario INT,
    @monto DECIMAL(18,2),
    @Mes INT = NULL,      -- Opcional: Mes (1=Enero, 2=Febrero, etc.)
    @Anio INT = NULL      -- Opcional: Año (ej. 2025)
AS
BEGIN
    SET NOCOUNT ON;

    -- Verificar que el usuario tenga rol "administradorWM" y perfil "superAdministradorWM"
    IF NOT EXISTS (
        SELECT 1
        FROM USUARIO_WM u
        INNER JOIN ROL_WM r ON u.idRol = r.idRol
        INNER JOIN PERFIL_WM p ON r.idPerfil = p.idPerfil
        WHERE u.idUsuario = @idUsuario
          AND r.nombreRol = 'administradorWM'
          AND p.nombrePerfil = 'superAdministradorWM'
    )
    BEGIN
        PRINT 'Usuario no autorizado para registrar el monto.';
        RETURN;
    END

    DECLARE @fecha DATETIME;
    IF @Mes IS NOT NULL AND @Anio IS NOT NULL
        -- Se construye la fecha usando el día actual del sistema
        SET @fecha = DATEFROMPARTS(@Anio, @Mes, DAY(GETDATE()))
    ELSE
        SET @fecha = GETDATE();

    INSERT INTO PRESUPUESTO_WM (idComite, idUsuario, montoPresupuesto, fechaHoraPresupuesto, fechaCreacion)
    VALUES (@idComite, @idUsuario, @monto, @fecha, GETDATE());
END;

GO
